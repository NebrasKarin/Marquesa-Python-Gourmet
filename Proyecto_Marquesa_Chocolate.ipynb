# %% [markdown]
# # Proyecto: Marquesa de Chocolate Gourmet 🍫
#
# Este postre es una evolución creativa de la marquesa tradicional, utilizando una técnica de emulsión en licuadora para lograr una textura de mousse cremosa.
#
# ### 📋 Ingredientes Disponibles:
# * **Lácteos (Base de cremosidad):**
#     * 170g de Crema de Leche **Di Fiore** (Fría).
#     * 170g de Leche Condensada **Natulac** (Lo reservado de la receta anterior).
#     * 200ml de Crema Chantilly **Chanty Festa** (Fría).
# * **Sabor y Color:**
#     * 4 cucharadas de Cacao puro en polvo (sin azúcar).
#     * 2 cucharadas de bebida achocolatada (para equilibrar el dulzor).
# * **Estructura:**
#     * 192g de Plantillas **Le Biscuit** (Sabor chocolate).
#
# ### 🛠️ Técnica Especial:
# Se utilizará el método de **incorporación en hilo** de un almíbar de cacao casero sobre la base láctea licuada para asegurar una mezcla homogénea sin necesidad de batidora eléctrica.

# %%
# --- LÓGICA DE PROGRAMACIÓN DE LA RECETA ---

# Definición de variables con las cantidades exactas
crema_leche = 170
leche_condensada = 170
chantilly = 200
plantillas = 192
cacao = 4
bebida_chocolate = 2

# Cálculo de la mezcla total
volumen_total_crema = crema_leche + leche_condensada + chantilly

print("--- REPORTE DE PRODUCCIÓN: MARQUESA DE CHOCOLATE ---")
print(f"Volumen total de la crema de chocolate: {volumen_total_crema}ml/g")
print(f"Peso de galletas tipo plantilla: {plantillas}g")
print("Estado: Listo para el armado en frío.")

# Generación automática de la lista de compras/inventario
with open("Lista_Inventario_Chocolate.txt", "w") as f:
    f.write("INVENTARIO PARA MARQUESA DE CHOCOLATE\n")
    f.write("=====================================\n")
    f.write(f"- Crema de Leche Di Fiore: {crema_leche}g\n")
    f.write(f"- Leche Condensada Natulac: {leche_condensada}g\n")
    f.write(f"- Crema Chantilly: {chantilly}ml\n")
    f.write(f"- Plantillas Le Biscuit: {plantillas}g\n")
    f.write("- Cacao y Bebida achocolatada para el almíbar.")

print("\n¡Archivo 'Lista_Inventario_Chocolate.txt' generado con éxito!")
# Out:
# --- REPORTE DE PRODUCCIÓN: MARQUESA DE CHOCOLATE ---
# Volumen total de la crema de chocolate: 540ml/g
# Peso de galletas tipo plantilla: 192g
# Estado: Listo para el armado en frío.
#
# ¡Archivo 'Lista_Inventario_Chocolate.txt' generado con éxito!
